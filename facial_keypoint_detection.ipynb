# %% [markdown]
# #**FACIAL KEYPOINT DETECTION**
# This kernel experiments with various data augmentation techniques for facial keypoint detection.

# %% [markdown]
# ## **Importing Necessary Packages**

# %%
# Making necessary imports
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
# %matplotlib inline
from math import sin, cos, pi
import cv2
from tqdm.notebook import tqdm

from keras.layers.advanced_activations import LeakyReLU
from keras.models import Sequential, Model, load_model
from keras.layers import Activation, Convolution2D, MaxPooling2D, BatchNormalization, Flatten, Dense, Dropout, Conv2D,MaxPool2D, ZeroPadding2D
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from keras.optimizers import Adam

# %% [markdown]
# ## **Augmentation & Hyperparameter Settings**
# #### Experiment with various augmentation choices

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
horizontal_flip = True
rotation_augmentation = True
brightness_augmentation = True
shift_augmentation = True
random_noise_augmentation = True

include_unclean_data = True    # Whether to include samples with missing keypoint values. Note that the missing values would however be filled using Pandas' 'ffill' later.
sample_image_index = 20    # Index of sample train image used for visualizing various augmentations

rotation_angles = [12]    # Rotation angle in degrees (includes both clockwise & anti-clockwise rotations)
pixel_shifts = [12]    # Horizontal & vertical shift amount in pixels (includes shift from all 4 corners)

NUM_EPOCHS = 80
BATCH_SIZE = 64

# %% [markdown]
# ### **Reading Inputs to a Pandas DataFrame**

# %%
# %%time

train_file = '/content/drive/MyDrive/PROJECTS/Deep learning/Facial Keypoints Detection/dataset/training/training.csv'
test_file = '/content/drive/MyDrive/PROJECTS/Deep learning/Facial Keypoints Detection/dataset/test/test.csv'
idlookup_file = '/content/drive/MyDrive/PROJECTS/Deep learning/Facial Keypoints Detection/dataset/IdLookupTable.csv'
train_data = pd.read_csv(train_file)
test_data = pd.read_csv(test_file)
idlookup_data = pd.read_csv(idlookup_file)
# Out:
# CPU times: user 2.58 s, sys: 358 ms, total: 2.94 s
# Wall time: 8.8 s

# %% [markdown]
# ### **Function to Plot Facial Keypoints with Images**

# %%
def plot_sample(image, keypoint, axis, title):
    image = image.reshape(96,96)
    axis.imshow(image, cmap='gray')
    axis.scatter(keypoint[0::2], keypoint[1::2], marker='x', s=20,c='#FF0000')
    plt.title(title)

# %% [markdown]
# ## **Exploring Data**

# %%
train_data.head().T
# Out:
#                                                                            0  ...                                                  4
# left_eye_center_x                                                    66.0336  ...                                            66.7253
# left_eye_center_y                                                    39.0023  ...                                            39.6213
# right_eye_center_x                                                    30.227  ...                                            32.2448
# right_eye_center_y                                                   36.4217  ...                                             38.042
# left_eye_inner_corner_x                                              59.5821  ...                                            58.5659
# left_eye_inner_corner_y                                              39.6474  ...                                            39.6213
# left_eye_outer_corner_x                                              73.1303  ...                                            72.5159
# left_eye_outer_corner_y                                                39.97  ...                                            39.8845
# right_eye_inner_corner_x                                             36.3566  ...                                            36.9824
# right_eye_inner_corner_y                                             37.3894  ...                                            39.0949
# right_eye_outer_corner_x                                             23.4529  ...                                            22.5061
# right_eye_outer_corner_y                                             37.3894  ...                                            38.3052
# left_eyebrow_inner_end_x                                             56.9533  ...                                            57.2496
# left_eyebrow_inner_end_y                                             29.0336  ...                                            30.6722
# left_eyebrow_outer_end_x                                             80.2271  ...                                            77.7629
# left_eyebrow_outer_end_y                                             32.2281  ...                                            31.7372
# right_eyebrow_inner_end_x                                            40.2276  ...                                            38.0354
# right_eyebrow_inner_end_y                                            29.0023  ...                                            30.9354
# right_eyebrow_outer_end_x                                            16.3564  ...                                            15.9259
# right_eyebrow_outer_end_y                                            29.6475  ...                                            30.6722
# nose_tip_x                                                           44.4206  ...                                            43.2995
# nose_tip_y                                                           57.0668  ...                                            64.8895
# mouth_left_corner_x                                                  61.1953  ...                                            60.6714
# mouth_left_corner_y                                                  79.9702  ...                                            77.5232
# mouth_right_corner_x                                                 28.6145  ...                                            31.1918
# mouth_right_corner_y                                                  77.389  ...                                            76.9973
# mouth_center_top_lip_x                                               43.3126  ...                                            44.9627
# mouth_center_top_lip_y                                               72.9355  ...                                            73.7074
# mouth_center_bottom_lip_x                                            43.1307  ...                                            44.2271
# mouth_center_bottom_lip_y                                            84.4858  ...                                            86.8712
# Image                      238 236 237 238 240 240 239 241 241 243 240 23...  ...  147 148 160 196 215 214 216 217 219 220 206 18...
#
# [31 rows x 5 columns]

# %%
test_data.head()
# Out:
#    ImageId                                              Image
# 0        1  182 183 182 182 180 180 176 169 156 137 124 10...
# 1        2  76 87 81 72 65 59 64 76 69 42 31 38 49 58 58 4...
# 2        3  177 176 174 170 169 169 168 166 166 166 161 14...
# 3        4  176 174 174 175 174 174 176 176 175 171 165 15...
# 4        5  50 47 44 101 144 149 120 58 48 42 35 35 37 39 ...

# %%
idlookup_data.head().T
# Out:
#                              0  ...                        4
# RowId                        1  ...                        5
# ImageId                      1  ...                        1
# FeatureName  left_eye_center_x  ...  left_eye_inner_corner_x
# Location                   NaN  ...                      NaN
#
# [4 rows x 5 columns]

# %% [markdown]
# ### **Check for any Images with Missing Pixel Values**

# %%
print("Length of train data: {}".format(len(train_data)))
print("Number of Images with missing pixel values: {}".format(len(train_data) - int(train_data.Image.apply(lambda x: len(x.split())).value_counts().values)))
# Out:
# Length of train data: 7049
# Number of Images with missing pixel values: 0

# %% [markdown]
# ### **Find Columns having Null Values and their Counts**

# %%
train_data.isnull().sum()
# Out:
# left_eye_center_x              10
# left_eye_center_y              10
# right_eye_center_x             13
# right_eye_center_y             13
# left_eye_inner_corner_x      4778
# left_eye_inner_corner_y      4778
# left_eye_outer_corner_x      4782
# left_eye_outer_corner_y      4782
# right_eye_inner_corner_x     4781
# right_eye_inner_corner_y     4781
# right_eye_outer_corner_x     4781
# right_eye_outer_corner_y     4781
# left_eyebrow_inner_end_x     4779
# left_eyebrow_inner_end_y     4779
# left_eyebrow_outer_end_x     4824
# left_eyebrow_outer_end_y     4824
# right_eyebrow_inner_end_x    4779
# right_eyebrow_inner_end_y    4779
# right_eyebrow_outer_end_x    4813
# right_eyebrow_outer_end_y    4813
# nose_tip_x                      0
# nose_tip_y                      0
# mouth_left_corner_x          4780
# mouth_left_corner_y          4780
# mouth_right_corner_x         4779
# mouth_right_corner_y         4779
# mouth_center_top_lip_x       4774
# mouth_center_top_lip_y       4774
# mouth_center_bottom_lip_x      33
# mouth_center_bottom_lip_y      33
# Image                           0
# dtype: int64

# %% [markdown]
# #### We can observe that approx. 68% of data is missing for several keypoints

# %%
# %%time

clean_train_data = train_data.dropna()
print("clean_train_data shape: {}".format(np.shape(clean_train_data)))

# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.fillna.html
unclean_train_data = train_data.fillna(method = 'ffill')
print("unclean_train_data shape: {}\n".format(np.shape(unclean_train_data)))
# Out:
# clean_train_data shape: (2140, 31)
# unclean_train_data shape: (7049, 31)
#
# CPU times: user 11 ms, sys: 4.37 ms, total: 15.3 ms
# Wall time: 26.7 ms

# %% [markdown]
# ### **Separate Data into Clean & Unclean Subsets**

# %%
# %%time

def load_images(image_data):
    images = []
    for idx, sample in image_data.iterrows():
        image = np.array(sample['Image'].split(' '), dtype=int)
        image = np.reshape(image, (96,96,1))
        images.append(image)
    images = np.array(images)/255.
    return images

def load_keypoints(keypoint_data):
    keypoint_data = keypoint_data.drop('Image',axis = 1)
    keypoint_features = []
    for idx, sample_keypoints in keypoint_data.iterrows():
        keypoint_features.append(sample_keypoints)
    keypoint_features = np.array(keypoint_features, dtype = 'float')
    return keypoint_features

clean_train_images = load_images(clean_train_data)
print("Shape of clean_train_images: {}".format(np.shape(clean_train_images)))
clean_train_keypoints = load_keypoints(clean_train_data)
print("Shape of clean_train_keypoints: {}".format(np.shape(clean_train_keypoints)))
test_images = load_images(test_data)
print("Shape of test_images: {}".format(np.shape(test_images)))

train_images = clean_train_images
train_keypoints = clean_train_keypoints
fig, axis = plt.subplots()
plot_sample(clean_train_images[sample_image_index], clean_train_keypoints[sample_image_index], axis, "Sample image & keypoints")

if include_unclean_data:
    unclean_train_images = load_images(unclean_train_data)
    print("Shape of unclean_train_images: {}".format(np.shape(unclean_train_images)))
    unclean_train_keypoints = load_keypoints(unclean_train_data)
    print("Shape of unclean_train_keypoints: {}\n".format(np.shape(unclean_train_keypoints)))
    train_images = np.concatenate((train_images, unclean_train_images))
    train_keypoints = np.concatenate((train_keypoints, unclean_train_keypoints))
# Out:
# Shape of clean_train_images: (2140, 96, 96, 1)
# Shape of clean_train_keypoints: (2140, 30)
# Shape of test_images: (1783, 96, 96, 1)
# Shape of unclean_train_images: (7049, 96, 96, 1)
# Shape of unclean_train_keypoints: (7049, 30)
#
# CPU times: user 16.6 s, sys: 799 ms, total: 17.4 s
# Wall time: 17.4 s

# %% [markdown]
# ## **Data Augmentation**

# %% [markdown]
# ### **Performing Horizontal Flipping for Data Augmentation**

# %%
def left_right_flip(images, keypoints):
    flipped_keypoints = []
    flipped_images = np.flip(images, axis=2)   # Flip column-wise (axis=2)
    for idx, sample_keypoints in enumerate(keypoints):
        flipped_keypoints.append([96.-coor if idx%2==0 else coor for idx,coor in enumerate(sample_keypoints)])    # Subtract only X co-ordinates of keypoints from 96 for horizontal flipping
    return flipped_images, flipped_keypoints

if horizontal_flip:
    flipped_train_images, flipped_train_keypoints = left_right_flip(clean_train_images, clean_train_keypoints)
    print("Shape of flipped_train_images: {}".format(np.shape(flipped_train_images)))
    print("Shape of flipped_train_keypoints: {}".format(np.shape(flipped_train_keypoints)))
    train_images = np.concatenate((train_images, flipped_train_images))
    train_keypoints = np.concatenate((train_keypoints, flipped_train_keypoints))
    fig, axis = plt.subplots()
    plot_sample(flipped_train_images[sample_image_index], flipped_train_keypoints[sample_image_index], axis, "Horizontally Flipped")
# Out:
# Shape of flipped_train_images: (2140, 96, 96, 1)
# Shape of flipped_train_keypoints: (2140, 30)

# %% [markdown]
# ### **Performing Rotation Augmentation**

# %%
def rotate_augmentation(images, keypoints):
    rotated_images = []
    rotated_keypoints = []
    print("Augmenting for angles (in degrees): ")
    for angle in rotation_angles:    # Rotation augmentation for a list of angle values
        for angle in [angle,-angle]:
            print(f'{angle}', end='  ')
            M = cv2.getRotationMatrix2D((48,48), angle, 1.0)
            angle_rad = -angle*pi/180.     # Obtain angle in radians from angle in degrees (notice negative sign for change in clockwise vs anti-clockwise directions from conventional rotation to cv2's image rotation)
            # For train_images
            for image in images:
                rotated_image = cv2.warpAffine(image, M, (96,96), flags=cv2.INTER_CUBIC)
                rotated_images.append(rotated_image)
            # For train_keypoints
            for keypoint in keypoints:
                rotated_keypoint = keypoint - 48.    # Subtract the middle value of the image dimension
                for idx in range(0,len(rotated_keypoint),2):
                    # https://in.mathworks.com/matlabcentral/answers/93554-how-can-i-rotate-a-set-of-points-in-a-plane-by-a-certain-angle-about-an-arbitrary-point
                    temp=rotated_keypoint[idx];
                    rotated_keypoint[idx] = rotated_keypoint[idx]*cos(angle_rad)-rotated_keypoint[idx+1]*sin(angle_rad)
                    rotated_keypoint[idx+1] = temp*sin(angle_rad)+rotated_keypoint[idx+1]*cos(angle_rad)
                rotated_keypoint += 48.   # Add the earlier subtracted value
                rotated_keypoints.append(rotated_keypoint)
            
    return np.reshape(rotated_images,(-1,96,96,1)), rotated_keypoints

if rotation_augmentation:
    rotated_train_images, rotated_train_keypoints = rotate_augmentation(clean_train_images, clean_train_keypoints)
    print("\nShape of rotated_train_images: {}".format(np.shape(rotated_train_images)))
    print("Shape of rotated_train_keypoints: {}\n".format(np.shape(rotated_train_keypoints)))
    train_images = np.concatenate((train_images, rotated_train_images))
    train_keypoints = np.concatenate((train_keypoints, rotated_train_keypoints))
    fig, axis = plt.subplots()
    plot_sample(rotated_train_images[sample_image_index], rotated_train_keypoints[sample_image_index], axis, "Rotation Augmentation")
# Out:
# Augmenting for angles (in degrees):
# 12  -12
# Shape of rotated_train_images: (4280, 96, 96, 1)
# Shape of rotated_train_keypoints: (4280, 30)

# %% [markdown]
# ### **Performing Brightness Alteration for Data Augmentation**

# %%
def alter_brightness(images, keypoints):
    altered_brightness_images = []
    inc_brightness_images = np.clip(images*1.2, 0.0, 1.0)    # Increased brightness by a factor of 1.2 & clip any values outside the range of [-1,1]
    dec_brightness_images = np.clip(images*0.6, 0.0, 1.0)    # Decreased brightness by a factor of 0.6 & clip any values outside the range of [-1,1]
    altered_brightness_images.extend(inc_brightness_images)
    altered_brightness_images.extend(dec_brightness_images)
    return altered_brightness_images, np.concatenate((keypoints, keypoints))

if brightness_augmentation:
    altered_brightness_train_images, altered_brightness_train_keypoints = alter_brightness(clean_train_images, clean_train_keypoints)
    print(f"Shape of altered_brightness_train_images: {np.shape(altered_brightness_train_images)}")
    print(f"Shape of altered_brightness_train_keypoints: {np.shape(altered_brightness_train_keypoints)}")
    train_images = np.concatenate((train_images, altered_brightness_train_images))
    train_keypoints = np.concatenate((train_keypoints, altered_brightness_train_keypoints))
    fig, axis = plt.subplots()
    plot_sample(altered_brightness_train_images[sample_image_index], altered_brightness_train_keypoints[sample_image_index], axis, "Increased Brightness") 
    fig, axis = plt.subplots()
    plot_sample(altered_brightness_train_images[len(altered_brightness_train_images)//2+sample_image_index], altered_brightness_train_keypoints[len(altered_brightness_train_images)//2+sample_image_index], axis, "Decreased Brightness")
# Out:
# Shape of altered_brightness_train_images: (4280, 96, 96, 1)
# Shape of altered_brightness_train_keypoints: (4280, 30)

# %% [markdown]
# ### **Performing Horizontal & Vertical shift**

# %%
def shift_images(images, keypoints):
    shifted_images = []
    shifted_keypoints = []
    for shift in pixel_shifts:    # Augmenting over several pixel shift values
        for (shift_x,shift_y) in [(-shift,-shift),(-shift,shift),(shift,-shift),(shift,shift)]:
            M = np.float32([[1,0,shift_x],[0,1,shift_y]])
            for image, keypoint in zip(images, keypoints):
                shifted_image = cv2.warpAffine(image, M, (96,96), flags=cv2.INTER_CUBIC)
                shifted_keypoint = np.array([(point+shift_x) if idx%2==0 else (point+shift_y) for idx, point in enumerate(keypoint)])
                if np.all(0.0<shifted_keypoint) and np.all(shifted_keypoint<96.0):
                    shifted_images.append(shifted_image.reshape(96,96,1))
                    shifted_keypoints.append(shifted_keypoint)
    shifted_keypoints = np.clip(shifted_keypoints,0.0,96.0)
    return shifted_images, shifted_keypoints

if shift_augmentation:
    shifted_train_images, shifted_train_keypoints = shift_images(clean_train_images, clean_train_keypoints)
    print(f"Shape of shifted_train_images: {np.shape(shifted_train_images)}")
    print(f"Shape of shifted_train_keypoints: {np.shape(shifted_train_keypoints)}")
    train_images = np.concatenate((train_images, shifted_train_images))
    train_keypoints = np.concatenate((train_keypoints, shifted_train_keypoints))
    fig, axis = plt.subplots()
    plot_sample(shifted_train_images[sample_image_index], shifted_train_keypoints[sample_image_index], axis, "Shift Augmentation")
# Out:
# Shape of shifted_train_images: (6350, 96, 96, 1)
# Shape of shifted_train_keypoints: (6350, 30)

# %% [markdown]
# ### **Adding Random Noise for Data Augmentation**

# %%
def add_noise(images):
    noisy_images = []
    for image in images:
        noisy_image = cv2.add(image, 0.008*np.random.randn(96,96,1))    # Adding random normal noise to the input image & clip the resulting noisy image between [-1,1]
        noisy_images.append(noisy_image.reshape(96,96,1))
    return noisy_images

if random_noise_augmentation:
    noisy_train_images = add_noise(clean_train_images)
    print(f"Shape of noisy_train_images: {np.shape(noisy_train_images)}")
    train_images = np.concatenate((train_images, noisy_train_images))
    train_keypoints = np.concatenate((train_keypoints, clean_train_keypoints))
    fig, axis = plt.subplots()
    plot_sample(noisy_train_images[sample_image_index], clean_train_keypoints[sample_image_index], axis, "Random Noise Augmentation")
# Out:
# Shape of noisy_train_images: (2140, 96, 96, 1)

# %% [markdown]
# ## **Visualize Train images & Corresponding Keypoints**

# %%
print("Shape of final train_images: {}".format(np.shape(train_images)))
print("Shape of final train_keypoints: {}".format(np.shape(train_keypoints)))

print("\n Clean Train Data: ")
fig = plt.figure(figsize=(20,8))
for i in range(10):
    axis = fig.add_subplot(2, 5, i+1, xticks=[], yticks=[])
    plot_sample(clean_train_images[i], clean_train_keypoints[i], axis, "")
plt.show()

if include_unclean_data:
    print("Unclean Train Data: ")
    fig = plt.figure(figsize=(20,8))
    for i in range(10):
        axis = fig.add_subplot(2, 5, i+1, xticks=[], yticks=[])
        plot_sample(unclean_train_images[i], unclean_train_keypoints[i], axis, "")
    plt.show()

if horizontal_flip:
    print("Horizontal Flip Augmentation: ")
    fig = plt.figure(figsize=(20,8))
    for i in range(10):
        axis = fig.add_subplot(2, 5, i+1, xticks=[], yticks=[])
        plot_sample(flipped_train_images[i], flipped_train_keypoints[i], axis, "")
    plt.show()

if rotation_augmentation:
    print("Rotation Augmentation: ")
    fig = plt.figure(figsize=(20,8))
    for i in range(10):
        axis = fig.add_subplot(2, 5, i+1, xticks=[], yticks=[])
        plot_sample(rotated_train_images[i], rotated_train_keypoints[i], axis, "")
    plt.show()
    
if brightness_augmentation:
    print("Brightness Augmentation: ")
    fig = plt.figure(figsize=(20,8))
    for i in range(10):
        axis = fig.add_subplot(2, 5, i+1, xticks=[], yticks=[])
        plot_sample(altered_brightness_train_images[i], altered_brightness_train_keypoints[i], axis, "")
    plt.show()

if shift_augmentation:
    print("Shift Augmentation: ")
    fig = plt.figure(figsize=(20,8))
    for i in range(10):
        axis = fig.add_subplot(2, 5, i+1, xticks=[], yticks=[])
        plot_sample(shifted_train_images[i], shifted_train_keypoints[i], axis, "")
    plt.show()
    
if random_noise_augmentation:
    print("Random Noise Augmentation: ")
    fig = plt.figure(figsize=(20,8))
    for i in range(10):
        axis = fig.add_subplot(2, 5, i+1, xticks=[], yticks=[])
        plot_sample(noisy_train_images[i], clean_train_keypoints[i], axis, "")
    plt.show()
# Out:
# Shape of final train_images: (36939, 96, 96, 1)
# Shape of final train_keypoints: (36939, 30)
#
#  Clean Train Data:
# Unclean Train Data:
# Horizontal Flip Augmentation:
# Rotation Augmentation:
# Brightness Augmentation:
# Shift Augmentation:
# Random Noise Augmentation:

# %% [markdown]
# ### **Building a Model**

# %%
model = Sequential()

# Input dimensions: (None, 96, 96, 1)
model.add(Convolution2D(32, (3,3), padding='same', use_bias=False, input_shape=(96,96,1)))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())
# Input dimensions: (None, 96, 96, 32)
model.add(Convolution2D(32, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

# Input dimensions: (None, 48, 48, 32)
model.add(Convolution2D(64, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())
# Input dimensions: (None, 48, 48, 64)
model.add(Convolution2D(64, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

# Input dimensions: (None, 24, 24, 64)
model.add(Convolution2D(96, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())
# Input dimensions: (None, 24, 24, 96)
model.add(Convolution2D(96, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

# Input dimensions: (None, 12, 12, 96)
model.add(Convolution2D(128, (3,3),padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())
# Input dimensions: (None, 12, 12, 128)
model.add(Convolution2D(128, (3,3),padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

# Input dimensions: (None, 6, 6, 128)
model.add(Convolution2D(256, (3,3),padding='same',use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())
# Input dimensions: (None, 6, 6, 256)
model.add(Convolution2D(256, (3,3),padding='same',use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

# Input dimensions: (None, 3, 3, 256)
model.add(Convolution2D(512, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())
# Input dimensions: (None, 3, 3, 512)
model.add(Convolution2D(512, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())

# Input dimensions: (None, 3, 3, 512)
model.add(Flatten())
model.add(Dense(512,activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(30))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 96, 96, 32)        288
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 96, 96, 32)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 96, 96, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 96, 96, 32)        9216
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 96, 96, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 96, 96, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 48, 48, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 48, 48, 64)        18432
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 48, 48, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 48, 48, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 48, 48, 64)        36864
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 48, 48, 64)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 48, 48, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 24, 24, 96)        55296
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 24, 24, 96)        0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 24, 24, 96)        384
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 24, 24, 96)        82944
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 24, 24, 96)        0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 24, 24, 96)        384
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 96)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 12, 12, 128)       110592
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 12, 12, 128)       0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 12, 12, 128)       512
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 12, 12, 128)       147456
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 12, 12, 128)       0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 12, 12, 128)       512
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 6, 6, 256)         294912
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 6, 6, 256)         0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 6, 6, 256)         1024
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 6, 6, 256)         589824
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 6, 6, 256)         0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 6, 6, 256)         1024
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 3, 3, 256)         0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 3, 3, 512)         1179648
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 3, 3, 512)         0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 3, 3, 512)         2048
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 3, 3, 512)         2359296
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 3, 3, 512)         0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 3, 3, 512)         2048
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               2359808
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 7,268,670
# Trainable params: 7,264,318
# Non-trainable params: 4,352
# _________________________________________________________________

# %% [markdown]
# ## **Training the Model**

# %%
# %%time

# Load a pre-trained model (if present)
if os.path.exists('../input/data-augmentation-for-facial-keypoint-detection/best_model.hdf5'):
    model = load_model('../input/data-augmentation-for-facial-keypoint-detection/best_model.hdf5')

# Define necessary callbacks
checkpointer = ModelCheckpoint(filepath = 'best_model.hdf5', monitor='val_mae', verbose=1, save_best_only=True, mode='min')

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae', 'acc'])

# Train the model
history = model.fit(train_images, train_keypoints, epochs=NUM_EPOCHS, batch_size=BATCH_SIZE, validation_split=0.05, callbacks=[checkpointer])
# Out:
# Epoch 1/80
# 549/549 [==============================] - 44s 64ms/step - loss: 133.3492 - mae: 6.7109 - acc: 0.4443 - val_loss: 12.2323 - val_mae: 2.6268 - val_acc: 0.6313
#
# Epoch 00001: val_mae improved from inf to 2.62675, saving model to best_model.hdf5
# Epoch 2/80
# 549/549 [==============================] - 35s 64ms/step - loss: 28.7647 - mae: 3.3496 - acc: 0.6097 - val_loss: 23.5098 - val_mae: 4.0644 - val_acc: 0.6979
#
# Epoch 00002: val_mae did not improve from 2.62675
# Epoch 3/80
# 549/549 [==============================] - 37s 67ms/step - loss: 22.2883 - mae: 2.9163 - acc: 0.6605 - val_loss: 9.4438 - val_mae: 2.4034 - val_acc: 0.7082
#
# Epoch 00003: val_mae improved from 2.62675 to 2.40336, saving model to best_model.hdf5
# Epoch 4/80
# 549/549 [==============================] - 38s 68ms/step - loss: 19.4722 - mae: 2.7305 - acc: 0.6779 - val_loss: 9.5553 - val_mae: 2.3516 - val_acc: 0.7087
#
# Epoch 00004: val_mae improved from 2.40336 to 2.35158, saving model to best_model.hdf5
# Epoch 5/80
# 549/549 [==============================] - 37s 67ms/step - loss: 19.0108 - mae: 2.6580 - acc: 0.7004 - val_loss: 7.8355 - val_mae: 2.1563 - val_acc: 0.7293
#
# Epoch 00005: val_mae improved from 2.35158 to 2.15633, saving model to best_model.hdf5
# Epoch 6/80
# 549/549 [==============================] - 37s 68ms/step - loss: 15.9156 - mae: 2.4386 - acc: 0.7184 - val_loss: 6.9653 - val_mae: 1.9033 - val_acc: 0.7336
#
# Epoch 00006: val_mae improved from 2.15633 to 1.90327, saving model to best_model.hdf5
# Epoch 7/80
# 549/549 [==============================] - 37s 68ms/step - loss: 14.8673 - mae: 2.3702 - acc: 0.7239 - val_loss: 14.5308 - val_mae: 2.3693 - val_acc: 0.7347
#
# Epoch 00007: val_mae did not improve from 1.90327
# Epoch 8/80
# 549/549 [==============================] - 37s 68ms/step - loss: 13.8172 - mae: 2.2816 - acc: 0.7356 - val_loss: 4.3432 - val_mae: 1.5201 - val_acc: 0.7255
#
# Epoch 00008: val_mae improved from 1.90327 to 1.52005, saving model to best_model.hdf5
# Epoch 9/80
# 549/549 [==============================] - 37s 68ms/step - loss: 11.4906 - mae: 2.1490 - acc: 0.7539 - val_loss: 7.3517 - val_mae: 1.6999 - val_acc: 0.7455
#
# Epoch 00009: val_mae did not improve from 1.52005
# Epoch 10/80
# 549/549 [==============================] - 37s 68ms/step - loss: 11.8843 - mae: 2.1823 - acc: 0.7529 - val_loss: 4.4896 - val_mae: 1.5145 - val_acc: 0.7699
#
# Epoch 00010: val_mae improved from 1.52005 to 1.51451, saving model to best_model.hdf5
# Epoch 11/80
# 549/549 [==============================] - 38s 68ms/step - loss: 10.0689 - mae: 2.0615 - acc: 0.7598 - val_loss: 7.3726 - val_mae: 1.9809 - val_acc: 0.7385
#
# Epoch 00011: val_mae did not improve from 1.51451
# Epoch 12/80
# 549/549 [==============================] - 37s 68ms/step - loss: 9.5135 - mae: 2.0449 - acc: 0.7737 - val_loss: 5.0496 - val_mae: 1.6234 - val_acc: 0.7103
#
# Epoch 00012: val_mae did not improve from 1.51451
# Epoch 13/80
# 549/549 [==============================] - 37s 68ms/step - loss: 9.1173 - mae: 2.0074 - acc: 0.7705 - val_loss: 14.7402 - val_mae: 1.7419 - val_acc: 0.7677
#
# Epoch 00013: val_mae did not improve from 1.51451
# Epoch 14/80
# 549/549 [==============================] - 37s 68ms/step - loss: 9.5036 - mae: 2.0379 - acc: 0.7701 - val_loss: 8.1370 - val_mae: 2.0474 - val_acc: 0.7694
#
# Epoch 00014: val_mae did not improve from 1.51451
# Epoch 15/80
# 549/549 [==============================] - 37s 68ms/step - loss: 8.3455 - mae: 1.9621 - acc: 0.7832 - val_loss: 3.6198 - val_mae: 1.3244 - val_acc: 0.7981
#
# Epoch 00015: val_mae improved from 1.51451 to 1.32444, saving model to best_model.hdf5
# Epoch 16/80
# 549/549 [==============================] - 37s 68ms/step - loss: 7.2136 - mae: 1.8828 - acc: 0.7863 - val_loss: 7.1480 - val_mae: 2.2280 - val_acc: 0.7970
#
# Epoch 00016: val_mae did not improve from 1.32444
# Epoch 17/80
# 549/549 [==============================] - 37s 68ms/step - loss: 8.0118 - mae: 1.9231 - acc: 0.7895 - val_loss: 3.9398 - val_mae: 1.5062 - val_acc: 0.7753
#
# Epoch 00017: val_mae did not improve from 1.32444
# Epoch 18/80
# 549/549 [==============================] - 37s 68ms/step - loss: 8.0309 - mae: 1.9531 - acc: 0.7888 - val_loss: 4.6982 - val_mae: 1.6225 - val_acc: 0.7666
#
# Epoch 00018: val_mae did not improve from 1.32444
# Epoch 19/80
# 549/549 [==============================] - 37s 68ms/step - loss: 6.1915 - mae: 1.7794 - acc: 0.8023 - val_loss: 4.7896 - val_mae: 1.7372 - val_acc: 0.7726
#
# Epoch 00019: val_mae did not improve from 1.32444
# Epoch 20/80
# 549/549 [==============================] - 37s 68ms/step - loss: 6.9247 - mae: 1.8591 - acc: 0.8011 - val_loss: 3.2293 - val_mae: 1.2963 - val_acc: 0.8029
#
# Epoch 00020: val_mae improved from 1.32444 to 1.29635, saving model to best_model.hdf5
# Epoch 21/80
# 549/549 [==============================] - 37s 68ms/step - loss: 6.6648 - mae: 1.8216 - acc: 0.8008 - val_loss: 3.6912 - val_mae: 1.4233 - val_acc: 0.8045
#
# Epoch 00021: val_mae did not improve from 1.29635
# Epoch 22/80
# 549/549 [==============================] - 37s 68ms/step - loss: 7.0097 - mae: 1.8508 - acc: 0.8026 - val_loss: 3.9513 - val_mae: 1.4918 - val_acc: 0.7672
#
# Epoch 00022: val_mae did not improve from 1.29635
# Epoch 23/80
# 549/549 [==============================] - 37s 68ms/step - loss: 6.9111 - mae: 1.8520 - acc: 0.7970 - val_loss: 4.4414 - val_mae: 1.5706 - val_acc: 0.7818
#
# Epoch 00023: val_mae did not improve from 1.29635
# Epoch 24/80
# 549/549 [==============================] - 37s 68ms/step - loss: 6.0619 - mae: 1.7668 - acc: 0.8056 - val_loss: 10.0640 - val_mae: 1.5703 - val_acc: 0.7916
#
# Epoch 00024: val_mae did not improve from 1.29635
# Epoch 25/80
# 549/549 [==============================] - 37s 68ms/step - loss: 5.9885 - mae: 1.7750 - acc: 0.8145 - val_loss: 3.2776 - val_mae: 1.2212 - val_acc: 0.7888
#
# Epoch 00025: val_mae improved from 1.29635 to 1.22124, saving model to best_model.hdf5
# Epoch 26/80
# 549/549 [==============================] - 37s 68ms/step - loss: 5.9456 - mae: 1.7687 - acc: 0.8123 - val_loss: 3.4206 - val_mae: 1.2819 - val_acc: 0.7867
#
# Epoch 00026: val_mae did not improve from 1.22124
# Epoch 27/80
# 549/549 [==============================] - 37s 68ms/step - loss: 5.8433 - mae: 1.7380 - acc: 0.8065 - val_loss: 3.3566 - val_mae: 1.3595 - val_acc: 0.7910
#
# Epoch 00027: val_mae did not improve from 1.22124
# Epoch 28/80
# 549/549 [==============================] - 37s 68ms/step - loss: 5.2368 - mae: 1.7097 - acc: 0.8217 - val_loss: 2.1631 - val_mae: 1.1492 - val_acc: 0.7905
#
# Epoch 00028: val_mae improved from 1.22124 to 1.14919, saving model to best_model.hdf5
# Epoch 29/80
# 549/549 [==============================] - 37s 68ms/step - loss: 4.7708 - mae: 1.6519 - acc: 0.8262 - val_loss: 1.7709 - val_mae: 1.0009 - val_acc: 0.7818
#
# Epoch 00029: val_mae improved from 1.14919 to 1.00085, saving model to best_model.hdf5
# Epoch 30/80
# 549/549 [==============================] - 37s 68ms/step - loss: 5.2779 - mae: 1.6858 - acc: 0.8207 - val_loss: 3.4946 - val_mae: 1.2889 - val_acc: 0.7650
#
# Epoch 00030: val_mae did not improve from 1.00085
# Epoch 31/80
# 549/549 [==============================] - 38s 68ms/step - loss: 6.0271 - mae: 1.7556 - acc: 0.8043 - val_loss: 5.1510 - val_mae: 1.3794 - val_acc: 0.7504
#
# Epoch 00031: val_mae did not improve from 1.00085
# Epoch 32/80
# 549/549 [==============================] - 37s 68ms/step - loss: 5.8892 - mae: 1.7553 - acc: 0.8185 - val_loss: 3.1460 - val_mae: 1.4160 - val_acc: 0.8246
#
# Epoch 00032: val_mae did not improve from 1.00085
# Epoch 33/80
# 549/549 [==============================] - 37s 68ms/step - loss: 5.0507 - mae: 1.6838 - acc: 0.8250 - val_loss: 1.4595 - val_mae: 0.9109 - val_acc: 0.8581
#
# Epoch 00033: val_mae improved from 1.00085 to 0.91085, saving model to best_model.hdf5
# Epoch 34/80
# 549/549 [==============================] - 38s 68ms/step - loss: 4.5275 - mae: 1.6119 - acc: 0.8356 - val_loss: 3.8665 - val_mae: 1.6101 - val_acc: 0.8468
#
# Epoch 00034: val_mae did not improve from 0.91085
# Epoch 35/80
# 549/549 [==============================] - 38s 68ms/step - loss: 4.4005 - mae: 1.5937 - acc: 0.8380 - val_loss: 1.8509 - val_mae: 1.0859 - val_acc: 0.8517
#
# Epoch 00035: val_mae did not improve from 0.91085
# Epoch 36/80
# 549/549 [==============================] - 37s 68ms/step - loss: 4.9383 - mae: 1.6373 - acc: 0.8320 - val_loss: 3.1490 - val_mae: 1.2024 - val_acc: 0.7851
#
# Epoch 00036: val_mae did not improve from 0.91085
# Epoch 37/80
# 549/549 [==============================] - 37s 68ms/step - loss: 5.9326 - mae: 1.7385 - acc: 0.8162 - val_loss: 2.3678 - val_mae: 1.0818 - val_acc: 0.8267
#
# Epoch 00037: val_mae did not improve from 0.91085
# Epoch 38/80
# 549/549 [==============================] - 37s 68ms/step - loss: 4.9648 - mae: 1.6494 - acc: 0.8252 - val_loss: 3.7030 - val_mae: 1.1165 - val_acc: 0.8246
#
# Epoch 00038: val_mae did not improve from 0.91085
# Epoch 39/80
# 549/549 [==============================] - 37s 68ms/step - loss: 5.0940 - mae: 1.6457 - acc: 0.8326 - val_loss: 1.9722 - val_mae: 1.1001 - val_acc: 0.8473
#
# Epoch 00039: val_mae did not improve from 0.91085
# Epoch 40/80
# 549/549 [==============================] - 37s 68ms/step - loss: 4.4390 - mae: 1.5897 - acc: 0.8391 - val_loss: 1.5574 - val_mae: 0.9622 - val_acc: 0.8560
#
# Epoch 00040: val_mae did not improve from 0.91085
# Epoch 41/80
# 549/549 [==============================] - 37s 68ms/step - loss: 4.1374 - mae: 1.5489 - acc: 0.8444 - val_loss: 1.8407 - val_mae: 1.0676 - val_acc: 0.8571
#
# Epoch 00041: val_mae did not improve from 0.91085
# Epoch 42/80
# 549/549 [==============================] - 37s 68ms/step - loss: 4.4227 - mae: 1.5997 - acc: 0.8434 - val_loss: 1.8434 - val_mae: 1.0858 - val_acc: 0.8544
#
# Epoch 00042: val_mae did not improve from 0.91085
# Epoch 43/80
# 549/549 [==============================] - 37s 68ms/step - loss: 4.4227 - mae: 1.5981 - acc: 0.8489 - val_loss: 1.6908 - val_mae: 1.0108 - val_acc: 0.8468
#
# Epoch 00043: val_mae did not improve from 0.91085
# Epoch 44/80
# 549/549 [==============================] - 37s 68ms/step - loss: 4.2281 - mae: 1.5643 - acc: 0.8468 - val_loss: 1.3369 - val_mae: 0.8612 - val_acc: 0.8711
#
# Epoch 00044: val_mae improved from 0.91085 to 0.86117, saving model to best_model.hdf5
# Epoch 45/80
# 549/549 [==============================] - 37s 68ms/step - loss: 4.8243 - mae: 1.6009 - acc: 0.8421 - val_loss: 2.3263 - val_mae: 1.1385 - val_acc: 0.8246
#
# Epoch 00045: val_mae did not improve from 0.86117
# Epoch 46/80
# 549/549 [==============================] - 37s 68ms/step - loss: 5.2285 - mae: 1.6619 - acc: 0.8197 - val_loss: 1.6934 - val_mae: 0.9807 - val_acc: 0.8322
#
# Epoch 00046: val_mae did not improve from 0.86117
# Epoch 47/80
# 549/549 [==============================] - 37s 68ms/step - loss: 4.4761 - mae: 1.5973 - acc: 0.8347 - val_loss: 4.4141 - val_mae: 1.1769 - val_acc: 0.8235
#
# Epoch 00047: val_mae did not improve from 0.86117
# Epoch 48/80
# 549/549 [==============================] - 37s 68ms/step - loss: 5.0708 - mae: 1.6552 - acc: 0.8284 - val_loss: 1.7375 - val_mae: 1.0143 - val_acc: 0.8760
#
# Epoch 00048: val_mae did not improve from 0.86117
# Epoch 49/80
# 549/549 [==============================] - 37s 68ms/step - loss: 4.1532 - mae: 1.5446 - acc: 0.8416 - val_loss: 1.2302 - val_mae: 0.8455 - val_acc: 0.8733
#
# Epoch 00049: val_mae improved from 0.86117 to 0.84547, saving model to best_model.hdf5
# Epoch 50/80
# 549/549 [==============================] - 37s 68ms/step - loss: 4.1083 - mae: 1.5308 - acc: 0.8443 - val_loss: 1.0749 - val_mae: 0.7831 - val_acc: 0.8728
#
# Epoch 00050: val_mae improved from 0.84547 to 0.78307, saving model to best_model.hdf5
# Epoch 51/80
# 549/549 [==============================] - 37s 68ms/step - loss: 4.1911 - mae: 1.5497 - acc: 0.8457 - val_loss: 3.4161 - val_mae: 1.3690 - val_acc: 0.8636
#
# Epoch 00051: val_mae did not improve from 0.78307
# Epoch 52/80
# 549/549 [==============================] - 37s 68ms/step - loss: 4.0396 - mae: 1.5254 - acc: 0.8486 - val_loss: 3.7047 - val_mae: 1.6566 - val_acc: 0.8868
#
# Epoch 00052: val_mae did not improve from 0.78307
# Epoch 53/80
# 549/549 [==============================] - 37s 68ms/step - loss: 4.0081 - mae: 1.5161 - acc: 0.8532 - val_loss: 2.5948 - val_mae: 1.3630 - val_acc: 0.8787
#
# Epoch 00053: val_mae did not improve from 0.78307
# Epoch 54/80
# 549/549 [==============================] - 37s 68ms/step - loss: 3.9973 - mae: 1.5158 - acc: 0.8556 - val_loss: 1.0789 - val_mae: 0.7915 - val_acc: 0.8798
#
# Epoch 00054: val_mae did not improve from 0.78307
# Epoch 55/80
# 549/549 [==============================] - 37s 68ms/step - loss: 3.9580 - mae: 1.5073 - acc: 0.8530 - val_loss: 2.8266 - val_mae: 1.4208 - val_acc: 0.8793
#
# Epoch 00055: val_mae did not improve from 0.78307
# Epoch 56/80
# 549/549 [==============================] - 37s 68ms/step - loss: 4.0681 - mae: 1.5305 - acc: 0.8541 - val_loss: 1.1338 - val_mae: 0.8081 - val_acc: 0.8073
#
# Epoch 00056: val_mae did not improve from 0.78307
# Epoch 57/80
# 549/549 [==============================] - 37s 68ms/step - loss: 4.1486 - mae: 1.5245 - acc: 0.8495 - val_loss: 2.6650 - val_mae: 1.2643 - val_acc: 0.8441
#
# Epoch 00057: val_mae did not improve from 0.78307
# Epoch 58/80
# 549/549 [==============================] - 37s 68ms/step - loss: 5.1925 - mae: 1.6428 - acc: 0.8303 - val_loss: 2.9908 - val_mae: 1.2248 - val_acc: 0.8522
#
# Epoch 00058: val_mae did not improve from 0.78307
# Epoch 59/80
# 549/549 [==============================] - 37s 68ms/step - loss: 4.2079 - mae: 1.5451 - acc: 0.8473 - val_loss: 2.3928 - val_mae: 1.2598 - val_acc: 0.8527
#
# Epoch 00059: val_mae did not improve from 0.78307
# Epoch 60/80
# 549/549 [==============================] - 37s 68ms/step - loss: 4.2218 - mae: 1.5319 - acc: 0.8472 - val_loss: 1.5219 - val_mae: 0.9250 - val_acc: 0.8619
#
# Epoch 00060: val_mae did not improve from 0.78307
# Epoch 61/80
# 549/549 [==============================] - 37s 68ms/step - loss: 3.9211 - mae: 1.4930 - acc: 0.8508 - val_loss: 3.0028 - val_mae: 1.4748 - val_acc: 0.8760
#
# Epoch 00061: val_mae did not improve from 0.78307
# Epoch 62/80
# 549/549 [==============================] - 38s 68ms/step - loss: 3.8584 - mae: 1.4974 - acc: 0.8504 - val_loss: 1.4081 - val_mae: 0.9213 - val_acc: 0.8776
#
# Epoch 00062: val_mae did not improve from 0.78307
# Epoch 63/80
# 549/549 [==============================] - 37s 68ms/step - loss: 3.9554 - mae: 1.5124 - acc: 0.8562 - val_loss: 1.1112 - val_mae: 0.8152 - val_acc: 0.8917
#
# Epoch 00063: val_mae did not improve from 0.78307
# Epoch 64/80
# 549/549 [==============================] - 37s 68ms/step - loss: 3.8634 - mae: 1.4945 - acc: 0.8614 - val_loss: 1.6364 - val_mae: 1.0602 - val_acc: 0.8917
#
# Epoch 00064: val_mae did not improve from 0.78307
# Epoch 65/80
# 549/549 [==============================] - 37s 68ms/step - loss: 3.7759 - mae: 1.4782 - acc: 0.8566 - val_loss: 0.9511 - val_mae: 0.7477 - val_acc: 0.8630
#
# Epoch 00065: val_mae improved from 0.78307 to 0.74772, saving model to best_model.hdf5
# Epoch 66/80
# 549/549 [==============================] - 37s 68ms/step - loss: 4.0493 - mae: 1.5296 - acc: 0.8608 - val_loss: 2.2874 - val_mae: 1.2643 - val_acc: 0.8928
#
# Epoch 00066: val_mae did not improve from 0.74772
# Epoch 67/80
# 549/549 [==============================] - 37s 68ms/step - loss: 3.7063 - mae: 1.4588 - acc: 0.8600 - val_loss: 8.9387 - val_mae: 1.6077 - val_acc: 0.7602
#
# Epoch 00067: val_mae did not improve from 0.74772
# Epoch 68/80
# 549/549 [==============================] - 37s 68ms/step - loss: 5.9944 - mae: 1.6859 - acc: 0.8207 - val_loss: 1.9043 - val_mae: 1.0748 - val_acc: 0.8419
#
# Epoch 00068: val_mae did not improve from 0.74772
# Epoch 69/80
# 549/549 [==============================] - 37s 68ms/step - loss: 4.0916 - mae: 1.5044 - acc: 0.8443 - val_loss: 1.3219 - val_mae: 0.9022 - val_acc: 0.8576
#
# Epoch 00069: val_mae did not improve from 0.74772
# Epoch 70/80
# 549/549 [==============================] - 37s 68ms/step - loss: 3.8668 - mae: 1.4952 - acc: 0.8556 - val_loss: 1.1068 - val_mae: 0.8259 - val_acc: 0.8814
#
# Epoch 00070: val_mae did not improve from 0.74772
# Epoch 71/80
# 549/549 [==============================] - 37s 68ms/step - loss: 3.6959 - mae: 1.4637 - acc: 0.8584 - val_loss: 1.7999 - val_mae: 1.0826 - val_acc: 0.8825
#
# Epoch 00071: val_mae did not improve from 0.74772
# Epoch 72/80
# 549/549 [==============================] - 37s 68ms/step - loss: 3.7708 - mae: 1.4789 - acc: 0.8588 - val_loss: 0.9496 - val_mae: 0.7528 - val_acc: 0.8744
#
# Epoch 00072: val_mae did not improve from 0.74772
# Epoch 73/80
# 549/549 [==============================] - 37s 68ms/step - loss: 3.7143 - mae: 1.4588 - acc: 0.8628 - val_loss: 0.8862 - val_mae: 0.7325 - val_acc: 0.8847
#
# Epoch 00073: val_mae improved from 0.74772 to 0.73252, saving model to best_model.hdf5
# Epoch 74/80
# 549/549 [==============================] - 37s 68ms/step - loss: 3.6032 - mae: 1.4435 - acc: 0.8609 - val_loss: 1.2156 - val_mae: 0.8897 - val_acc: 0.8966
#
# Epoch 00074: val_mae did not improve from 0.73252
# Epoch 75/80
# 549/549 [==============================] - 37s 68ms/step - loss: 3.5581 - mae: 1.4354 - acc: 0.8591 - val_loss: 0.9618 - val_mae: 0.7645 - val_acc: 0.8988
#
# Epoch 00075: val_mae did not improve from 0.73252
# Epoch 76/80
# 549/549 [==============================] - 37s 68ms/step - loss: 3.6200 - mae: 1.4453 - acc: 0.8604 - val_loss: 0.8987 - val_mae: 0.7316 - val_acc: 0.8744
#
# Epoch 00076: val_mae improved from 0.73252 to 0.73161, saving model to best_model.hdf5
# Epoch 77/80
# 549/549 [==============================] - 37s 68ms/step - loss: 3.5490 - mae: 1.4284 - acc: 0.8594 - val_loss: 0.9841 - val_mae: 0.7721 - val_acc: 0.9053
#
# Epoch 00077: val_mae did not improve from 0.73161
# Epoch 78/80
# 549/549 [==============================] - 37s 68ms/step - loss: 3.6217 - mae: 1.4459 - acc: 0.8594 - val_loss: 1.4980 - val_mae: 0.9951 - val_acc: 0.8825
#
# Epoch 00078: val_mae did not improve from 0.73161
# Epoch 79/80
# 549/549 [==============================] - 37s 68ms/step - loss: 4.6336 - mae: 1.5360 - acc: 0.8491 - val_loss: 2.0009 - val_mae: 1.0278 - val_acc: 0.8441
#
# Epoch 00079: val_mae did not improve from 0.73161
# Epoch 80/80
# 549/549 [==============================] - 37s 68ms/step - loss: 4.0753 - mae: 1.4923 - acc: 0.8446 - val_loss: 1.0094 - val_mae: 0.7658 - val_acc: 0.8419
#
# Epoch 00080: val_mae did not improve from 0.73161
# CPU times: user 23min 33s, sys: 15min 44s, total: 39min 18s
# Wall time: 49min 57s

# %%
# summarize history for mean_absolute_error
try:
    plt.plot(history.history['mae'])
    plt.plot(history.history['val_mae'])
    plt.title('Mean Absolute Error vs Epoch')
    plt.ylabel('Mean Absolute Error')
    plt.xlabel('Epochs')
    plt.legend(['train', 'validation'], loc='upper right')
    plt.show()
    # summarize history for accuracy
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
    plt.title('Accuracy vs Epoch')
    plt.ylabel('Accuracy')
    plt.xlabel('Epochs')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Loss vs Epoch')
    plt.ylabel('Loss')
    plt.xlabel('Epochs')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()
except:
    print("One of the metrics used for plotting graphs is missing! See 'model.compile()'s `metrics` argument.")

# %% [markdown]
# ## **Fit the Model to get the Best Model with Best Train MAE**

# %%
# %%time

# Modify ModelCheckpoint callback to save model with best train mae to disk (instead of best validation mae)
checkpointer = ModelCheckpoint(filepath = 'best_model.hdf5', monitor='mae', verbose=1, save_best_only=True, mode='min')
model.fit(train_images, train_keypoints, epochs=NUM_EPOCHS, batch_size=BATCH_SIZE, callbacks=[checkpointer])
# Out:
# Epoch 1/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.5987 - mae: 1.4402 - acc: 0.8581
#
# Epoch 00001: mae improved from inf to 1.44021, saving model to best_model.hdf5
# Epoch 2/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.5678 - mae: 1.4330 - acc: 0.8615
#
# Epoch 00002: mae improved from 1.44021 to 1.43296, saving model to best_model.hdf5
# Epoch 3/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.6006 - mae: 1.4380 - acc: 0.8600
#
# Epoch 00003: mae did not improve from 1.43296
# Epoch 4/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.4692 - mae: 1.4144 - acc: 0.8638
#
# Epoch 00004: mae improved from 1.43296 to 1.41443, saving model to best_model.hdf5
# Epoch 5/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.4747 - mae: 1.4158 - acc: 0.8653
#
# Epoch 00005: mae did not improve from 1.41443
# Epoch 6/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.5053 - mae: 1.4214 - acc: 0.8667
#
# Epoch 00006: mae did not improve from 1.41443
# Epoch 7/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.4585 - mae: 1.4115 - acc: 0.8647
#
# Epoch 00007: mae improved from 1.41443 to 1.41155, saving model to best_model.hdf5
# Epoch 8/80
# 578/578 [==============================] - 39s 67ms/step - loss: 4.4622 - mae: 1.5032 - acc: 0.8508
#
# Epoch 00008: mae did not improve from 1.41155
# Epoch 9/80
# 578/578 [==============================] - 39s 67ms/step - loss: 4.0193 - mae: 1.4791 - acc: 0.8515
#
# Epoch 00009: mae did not improve from 1.41155
# Epoch 10/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.6133 - mae: 1.4368 - acc: 0.8613
#
# Epoch 00010: mae did not improve from 1.41155
# Epoch 11/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.8042 - mae: 1.4588 - acc: 0.8579
#
# Epoch 00011: mae did not improve from 1.41155
# Epoch 12/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.4454 - mae: 1.4092 - acc: 0.8640
#
# Epoch 00012: mae improved from 1.41155 to 1.40920, saving model to best_model.hdf5
# Epoch 13/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.4763 - mae: 1.4133 - acc: 0.8653
#
# Epoch 00013: mae did not improve from 1.40920
# Epoch 14/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.3785 - mae: 1.3938 - acc: 0.8656
#
# Epoch 00014: mae improved from 1.40920 to 1.39384, saving model to best_model.hdf5
# Epoch 15/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.4130 - mae: 1.4027 - acc: 0.8691
#
# Epoch 00015: mae did not improve from 1.39384
# Epoch 16/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.3276 - mae: 1.3828 - acc: 0.8691
#
# Epoch 00016: mae improved from 1.39384 to 1.38280, saving model to best_model.hdf5
# Epoch 17/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.3922 - mae: 1.3959 - acc: 0.8680
#
# Epoch 00017: mae did not improve from 1.38280
# Epoch 18/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.2990 - mae: 1.3773 - acc: 0.8675
#
# Epoch 00018: mae improved from 1.38280 to 1.37729, saving model to best_model.hdf5
# Epoch 19/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.3701 - mae: 1.3890 - acc: 0.8672
#
# Epoch 00019: mae did not improve from 1.37729
# Epoch 20/80
# 578/578 [==============================] - 39s 67ms/step - loss: 4.1820 - mae: 1.4885 - acc: 0.8545
#
# Epoch 00020: mae did not improve from 1.37729
# Epoch 21/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.6287 - mae: 1.4318 - acc: 0.8574
#
# Epoch 00021: mae did not improve from 1.37729
# Epoch 22/80
# 578/578 [==============================] - 38s 66ms/step - loss: 3.6157 - mae: 1.4233 - acc: 0.8609
#
# Epoch 00022: mae did not improve from 1.37729
# Epoch 23/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.4556 - mae: 1.3964 - acc: 0.8626
#
# Epoch 00023: mae did not improve from 1.37729
# Epoch 24/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.2936 - mae: 1.3786 - acc: 0.8676
#
# Epoch 00024: mae did not improve from 1.37729
# Epoch 25/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.2964 - mae: 1.3777 - acc: 0.8686
#
# Epoch 00025: mae did not improve from 1.37729
# Epoch 26/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.3300 - mae: 1.3873 - acc: 0.8728
#
# Epoch 00026: mae did not improve from 1.37729
# Epoch 27/80
# 578/578 [==============================] - 38s 67ms/step - loss: 3.2138 - mae: 1.3572 - acc: 0.8702
#
# Epoch 00027: mae improved from 1.37729 to 1.35722, saving model to best_model.hdf5
# Epoch 28/80
# 578/578 [==============================] - 38s 66ms/step - loss: 3.3757 - mae: 1.3937 - acc: 0.8684
#
# Epoch 00028: mae did not improve from 1.35722
# Epoch 29/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.2192 - mae: 1.3597 - acc: 0.8713
#
# Epoch 00029: mae did not improve from 1.35722
# Epoch 30/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.2117 - mae: 1.3578 - acc: 0.8694
#
# Epoch 00030: mae did not improve from 1.35722
# Epoch 31/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.2708 - mae: 1.3698 - acc: 0.8694
#
# Epoch 00031: mae did not improve from 1.35722
# Epoch 32/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.2300 - mae: 1.3602 - acc: 0.8700
#
# Epoch 00032: mae did not improve from 1.35722
# Epoch 33/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.2114 - mae: 1.3583 - acc: 0.8718
#
# Epoch 00033: mae did not improve from 1.35722
# Epoch 34/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.1935 - mae: 1.3547 - acc: 0.8697
#
# Epoch 00034: mae improved from 1.35722 to 1.35466, saving model to best_model.hdf5
# Epoch 35/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.2178 - mae: 1.3607 - acc: 0.8706
#
# Epoch 00035: mae did not improve from 1.35466
# Epoch 36/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.7689 - mae: 1.4155 - acc: 0.8619
#
# Epoch 00036: mae did not improve from 1.35466
# Epoch 37/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.4628 - mae: 1.3998 - acc: 0.8627
#
# Epoch 00037: mae did not improve from 1.35466
# Epoch 38/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.3333 - mae: 1.3700 - acc: 0.8692
#
# Epoch 00038: mae did not improve from 1.35466
# Epoch 39/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.3148 - mae: 1.3713 - acc: 0.8654
#
# Epoch 00039: mae did not improve from 1.35466
# Epoch 40/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.1570 - mae: 1.3478 - acc: 0.8725
#
# Epoch 00040: mae improved from 1.35466 to 1.34783, saving model to best_model.hdf5
# Epoch 41/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.1699 - mae: 1.3490 - acc: 0.8714
#
# Epoch 00041: mae did not improve from 1.34783
# Epoch 42/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.1829 - mae: 1.3502 - acc: 0.8746
#
# Epoch 00042: mae did not improve from 1.34783
# Epoch 43/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.2051 - mae: 1.3578 - acc: 0.8745
#
# Epoch 00043: mae did not improve from 1.34783
# Epoch 44/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.0423 - mae: 1.3196 - acc: 0.8738
#
# Epoch 00044: mae improved from 1.34783 to 1.31962, saving model to best_model.hdf5
# Epoch 45/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.0946 - mae: 1.3319 - acc: 0.8747
#
# Epoch 00045: mae did not improve from 1.31962
# Epoch 46/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.6567 - mae: 1.3921 - acc: 0.8632
#
# Epoch 00046: mae did not improve from 1.31962
# Epoch 47/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.5352 - mae: 1.3848 - acc: 0.8618
#
# Epoch 00047: mae did not improve from 1.31962
# Epoch 48/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.2998 - mae: 1.3696 - acc: 0.8667
#
# Epoch 00048: mae did not improve from 1.31962
# Epoch 49/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.0902 - mae: 1.3316 - acc: 0.8732
#
# Epoch 00049: mae did not improve from 1.31962
# Epoch 50/80
# 578/578 [==============================] - 38s 67ms/step - loss: 3.0875 - mae: 1.3307 - acc: 0.8724
#
# Epoch 00050: mae did not improve from 1.31962
# Epoch 51/80
# 578/578 [==============================] - 38s 67ms/step - loss: 3.0811 - mae: 1.3282 - acc: 0.8759
#
# Epoch 00051: mae did not improve from 1.31962
# Epoch 52/80
# 578/578 [==============================] - 38s 66ms/step - loss: 3.0820 - mae: 1.3299 - acc: 0.8754
#
# Epoch 00052: mae did not improve from 1.31962
# Epoch 53/80
# 578/578 [==============================] - 38s 66ms/step - loss: 3.0751 - mae: 1.3261 - acc: 0.8731
#
# Epoch 00053: mae did not improve from 1.31962
# Epoch 54/80
# 578/578 [==============================] - 38s 66ms/step - loss: 3.0441 - mae: 1.3201 - acc: 0.8747
#
# Epoch 00054: mae did not improve from 1.31962
# Epoch 55/80
# 578/578 [==============================] - 38s 67ms/step - loss: 3.0498 - mae: 1.3215 - acc: 0.8765
#
# Epoch 00055: mae did not improve from 1.31962
# Epoch 56/80
# 578/578 [==============================] - 38s 66ms/step - loss: 3.0552 - mae: 1.3214 - acc: 0.8753
#
# Epoch 00056: mae did not improve from 1.31962
# Epoch 57/80
# 578/578 [==============================] - 38s 66ms/step - loss: 3.0391 - mae: 1.3182 - acc: 0.8752
#
# Epoch 00057: mae improved from 1.31962 to 1.31816, saving model to best_model.hdf5
# Epoch 58/80
# 578/578 [==============================] - 38s 67ms/step - loss: 3.1236 - mae: 1.3376 - acc: 0.8741
#
# Epoch 00058: mae did not improve from 1.31816
# Epoch 59/80
# 578/578 [==============================] - 38s 67ms/step - loss: 3.7940 - mae: 1.3995 - acc: 0.8587
#
# Epoch 00059: mae did not improve from 1.31816
# Epoch 60/80
# 578/578 [==============================] - 38s 67ms/step - loss: 3.2209 - mae: 1.3537 - acc: 0.8696
#
# Epoch 00060: mae did not improve from 1.31816
# Epoch 61/80
# 578/578 [==============================] - 38s 67ms/step - loss: 3.0832 - mae: 1.3297 - acc: 0.8718
#
# Epoch 00061: mae did not improve from 1.31816
# Epoch 62/80
# 578/578 [==============================] - 38s 67ms/step - loss: 3.0327 - mae: 1.3173 - acc: 0.8775
#
# Epoch 00062: mae improved from 1.31816 to 1.31727, saving model to best_model.hdf5
# Epoch 63/80
# 578/578 [==============================] - 38s 67ms/step - loss: 2.9951 - mae: 1.3095 - acc: 0.8758
#
# Epoch 00063: mae improved from 1.31727 to 1.30953, saving model to best_model.hdf5
# Epoch 64/80
# 578/578 [==============================] - 38s 67ms/step - loss: 2.9978 - mae: 1.3107 - acc: 0.8779
#
# Epoch 00064: mae did not improve from 1.30953
# Epoch 65/80
# 578/578 [==============================] - 39s 67ms/step - loss: 2.9768 - mae: 1.3074 - acc: 0.8783
#
# Epoch 00065: mae improved from 1.30953 to 1.30738, saving model to best_model.hdf5
# Epoch 66/80
# 578/578 [==============================] - 39s 67ms/step - loss: 2.9644 - mae: 1.3036 - acc: 0.8776
#
# Epoch 00066: mae improved from 1.30738 to 1.30363, saving model to best_model.hdf5
# Epoch 67/80
# 578/578 [==============================] - 38s 67ms/step - loss: 2.9766 - mae: 1.3081 - acc: 0.8799
#
# Epoch 00067: mae did not improve from 1.30363
# Epoch 68/80
# 578/578 [==============================] - 38s 67ms/step - loss: 2.9415 - mae: 1.2974 - acc: 0.8794
#
# Epoch 00068: mae improved from 1.30363 to 1.29739, saving model to best_model.hdf5
# Epoch 69/80
# 578/578 [==============================] - 39s 67ms/step - loss: 2.9473 - mae: 1.2979 - acc: 0.8802
#
# Epoch 00069: mae did not improve from 1.29739
# Epoch 70/80
# 578/578 [==============================] - 38s 67ms/step - loss: 3.5676 - mae: 1.3771 - acc: 0.8648
#
# Epoch 00070: mae did not improve from 1.29739
# Epoch 71/80
# 578/578 [==============================] - 39s 67ms/step - loss: 3.2675 - mae: 1.3462 - acc: 0.8679
#
# Epoch 00071: mae did not improve from 1.29739
# Epoch 72/80
# 578/578 [==============================] - 38s 67ms/step - loss: 3.0055 - mae: 1.3119 - acc: 0.8740
#
# Epoch 00072: mae did not improve from 1.29739
# Epoch 73/80
# 578/578 [==============================] - 38s 67ms/step - loss: 2.9465 - mae: 1.2992 - acc: 0.8754
#
# Epoch 00073: mae did not improve from 1.29739
# Epoch 74/80
# 578/578 [==============================] - 39s 67ms/step - loss: 2.9248 - mae: 1.2940 - acc: 0.8785
#
# Epoch 00074: mae improved from 1.29739 to 1.29402, saving model to best_model.hdf5
# Epoch 75/80
# 578/578 [==============================] - 38s 67ms/step - loss: 2.8886 - mae: 1.2854 - acc: 0.8793
#
# Epoch 00075: mae improved from 1.29402 to 1.28536, saving model to best_model.hdf5
# Epoch 76/80
# 578/578 [==============================] - 38s 66ms/step - loss: 2.8938 - mae: 1.2868 - acc: 0.8812
#
# Epoch 00076: mae did not improve from 1.28536
# Epoch 77/80
# 578/578 [==============================] - 38s 67ms/step - loss: 2.9135 - mae: 1.2927 - acc: 0.8786
#
# Epoch 00077: mae did not improve from 1.28536
# Epoch 78/80
# 578/578 [==============================] - 38s 66ms/step - loss: 2.9194 - mae: 1.2921 - acc: 0.8799
#
# Epoch 00078: mae did not improve from 1.28536
# Epoch 79/80
# 578/578 [==============================] - 38s 67ms/step - loss: 2.9186 - mae: 1.2913 - acc: 0.8793
#
# Epoch 00079: mae did not improve from 1.28536
# Epoch 80/80
# 578/578 [==============================] - 38s 66ms/step - loss: 2.8698 - mae: 1.2814 - acc: 0.8808
#
# Epoch 00080: mae improved from 1.28536 to 1.28137, saving model to best_model.hdf5
# CPU times: user 24min 9s, sys: 16min 39s, total: 40min 48s
# Wall time: 51min 30s

# %% [markdown]
# ## **Predicting on Test Set**

# %%
# %%time
 
model = load_model('best_model.hdf5')
test_preds = model.predict(test_images)
# Out:
# CPU times: user 1.04 s, sys: 269 ms, total: 1.31 s
# Wall time: 1.68 s

# %% [markdown]
# ## **Visualizing Test Predictions**

# %%
fig = plt.figure(figsize=(20,16))
for i in range(20):
    axis = fig.add_subplot(4, 5, i+1, xticks=[], yticks=[])
    plot_sample(test_images[i], test_preds[i], axis, "")
plt.show()

# %% [markdown]
# ## **Generating Submission File**

# %%
feature_names = list(idlookup_data['FeatureName'])
image_ids = list(idlookup_data['ImageId']-1)
row_ids = list(idlookup_data['RowId'])

feature_list = []
for feature in feature_names:
    feature_list.append(feature_names.index(feature))
    
predictions = []
for x,y in zip(image_ids, feature_list):
    predictions.append(test_preds[x][y])
    
row_ids = pd.Series(row_ids, name = 'RowId')
locations = pd.Series(predictions, name = 'Location')
locations = locations.clip(0.0,96.0)
submission_result = pd.concat([row_ids,locations],axis = 1)
submission_result.to_csv('submission.csv',index = False)
